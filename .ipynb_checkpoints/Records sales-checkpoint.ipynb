# %%
# # En la documentacion de este notebook podra obtener el detalle de cada columna y procesos hechos aqui.
# Document of this notebook can help you to understand all columns and process do here

# %% [markdown]
# #### Importacion de librerias
# #### Load librarys

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
pd.set_option('display.max_rows', 10)

# %%
data = pd.read_csv('top10xano.csv', decimal=',', thousands='.', encoding='utf-8')
data2 = pd.read_csv('top5000altime.csv')

# %% [markdown]
# # Dataset 1 - TopxYear

# %%
#Exploramos el csv data :
#Explore csv data :

data.keys()
# Out:
# Index(['Year', 'Ranking', 'Artist', 'Album', 'Worldwide Sales (Est.)', 'CDs',
#        'Tracks', 'Album Length', 'Hours', 'Minutes', 'Seconds', 'Genre'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 320 entries, 0 to 319
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Year                    320 non-null    int64
#  1   Ranking                 320 non-null    int64
#  2   Artist                  320 non-null    object
#  3   Album                   320 non-null    object
#  4   Worldwide Sales (Est.)  320 non-null    float64
#  5   CDs                     320 non-null    int64
#  6   Tracks                  320 non-null    int64
#  7   Album Length            320 non-null    object
#  8   Hours                   320 non-null    int64
#  9   Minutes                 320 non-null    int64
#  10  Seconds                 320 non-null    int64
#  11  Genre                   320 non-null    object
# dtypes: float64(1), int64(7), object(4)
# memory usage: 30.1+ KB

# %%
# Esta recopilacion desde que año cubre?
# Range years? 

ca = data['Year'].sort_values(ascending=True)
ca
# Out:
# 145    1990
# 271    1990
# 109    1990
# 115    1990
# 33     1990
#        ...
# 13     2021
# 10     2021
# 240    2021
# 114    2021
# 319    2021
# Name: Year, Length: 320, dtype: int64

# %%
data['Worldwide Sales (Est.)'].apply(type)
# Out:
# 0      <class 'float'>
# 1      <class 'float'>
# 2      <class 'float'>
# 3      <class 'float'>
# 4      <class 'float'>
#             ...
# 315    <class 'float'>
# 316    <class 'float'>
# 317    <class 'float'>
# 318    <class 'float'>
# 319    <class 'float'>
# Name: Worldwide Sales (Est.), Length: 320, dtype: object

# %%
# Hay valores faltantes? 
# there are missing values? 
print(data['Worldwide Sales (Est.)'].isnull().sum())
# Out:
# 0

# %%
# Tenemos que cambiar los valores de WSE dado que existe una inconsistencia en el registro. Object -> int64

# %%
# Definir una función que convierta una cadena (str) a flotante(float) manteniendo el formato adecuado.
# Make function to convert str values to float values keeping right data.
def to_float(x):
    try:
        # intentar convertir la cadena a flotante.
        # convert string to float values.
        return float(x)
    except:
        # si falla la conversión, intentar reemplazar el separador de miles y decimales y convertir a flotante
        # if convert fail, try replace comma.
        try:
            x = x.replace(',', '').replace('.', '.')
            return float(x)
        except:
            # si no se puede convertir, dejar el valor original
            return x

# %%
# aplicar la función a la columna "Worldwide Sales (Est.)" y sobrescribir los valores originales
# apply the function to the "Worldwide Sales (Est.)" column and overwrite the original values


data['Worldwide Sales (Est.)'] = data['Worldwide Sales (Est.)'].apply(to_float)

# %%
data['Worldwide Sales (Est.)']
# Out:
# 0       33000.00
# 1       32200.00
# 2      200000.00
# 3       48350.00
# 4       70120.00
#          ...
# 315     39800.00
# 316     30805.07
# 317     29473.98
# 318     34029.81
# 319     24013.68
# Name: Worldwide Sales (Est.), Length: 320, dtype: float64

# %% [markdown]
# # Álbums & Artistas

# %%
# Ordenamos los albums por la estimacion de ventas.
# Order by sales est.

WSE = data.sort_values(by='Worldwide Sales (Est.)', ascending=False)
WSE.head(20)
# Out:
#      Year  Ranking             Artist                     Album  \
# 118  1992        1    Whitney Houston  The Bodyguard Soundtrack
# 194  1999        1    Backstreet Boys                 Milennium
# 100  1997        1       Shania Twain              Come On Over
# 120  1995        1  Alanis Morissette        Jagged Little Pill
# 87   1991        1          Metallica                 Metallica
# ..    ...      ...                ...                       ...
# 287  2000        3        Linkin Park             Hybrid Theory
# 257  1999        2     Britney Spears     ...Baby One More Time
# 30   1991        3    Michael Jackson                 Dangerous
# 231  2002        1        Norah Jones         Come Away With Me
# 93   1992        3       Eric Clapton                 Unplugged
#
#      Worldwide Sales (Est.)  CDs  Tracks Album Length  Hours  Minutes  \
# 118                450000.0    1      13      0:57:44     96     5773
# 194                400000.0    1      12      0:48:11     80     4818
# 100                400000.0    1      16      1:00:06    100     6010
# 120                330000.0    1      13      0:57:23     96     5738
# 87                 330000.0    1      12      1:02:40    104     6267
# ..                      ...  ...     ...          ...    ...      ...
# 287                270000.0    1      12      0:37:45     63     3775
# 257                270000.0    1      11      0:42:20     71     4233
# 30                 270000.0    1      14      1:17:03    128     7705
# 231                270000.0    1      14      0:45:03     75     4505
# 93                 260000.0    1      14      1:01:47    103     6178
#
#      Seconds    Genre
# 118     3464      Pop
# 194     2891      Pop
# 100     3606  Country
# 120     3443     Rock
# 87      3760     Rock
# ..       ...      ...
# 287     2265     Rock
# 257     2540      Pop
# 30      4623      Pop
# 231     2703      Pop
# 93      3707     Rock
#
# [20 rows x 12 columns]

# %%
# Cambiamos el error de dato de "1" de los Beatles a su valor correcto que es "White álbum"
# Corrected error album of "The Beatles" album from "1" to "White álbum".

data['Album'] = data['Album'].replace('1', 'white Album')
data.to_csv('ETLtop10xano.csv', index=True)

# %%
# Filtrar los datos por los álbumes de Michael Jackson
# Filter data by Michael Jackson albums

MJ = data[data['Artist'] == 'Michael Jackson']

# Contar cuántos álbumes de Michael Jackson aparecen en el top por año.
# Count how many Michael Jackson albums appear in the top per year.

MJ_top_albums = MJ.groupby(['Year','Artist', 'Album', 'Ranking', 'Worldwide Sales (Est.)']).size().reset_index(name='AxY')

MJ_top_albums
# Out:
#    Year           Artist                                   Album  Ranking  \
# 0  1991  Michael Jackson                               Dangerous        3
# 1  1995  Michael Jackson  History: Past, Present & Future Book I        4
# 2  2003  Michael Jackson                             Number Ones        4
#
#    Worldwide Sales (Est.)  AxY
# 0              27000000.0    1
# 1              20000000.0    1
# 2               9592405.0    1

# %%
# Filtrar los datos por los álbumes de Phil Collins.
# Filter data by Phil Collins albums.

PC = data[data['Artist'] == 'Phil Collins']

# Contar cuántos álbumes de Phil Collins aparecen en el top por año.
# Count how many Phil Collins albums appear in the top per year.

PC_top_albums = PC.groupby(['Year','Artist', 'Album', 'Ranking', 'Worldwide Sales (Est.)']).size().reset_index(name='AxY')

PC_top_albums
# Out:
#    Year        Artist                  Album  Ranking  Worldwide Sales (Est.)  \
# 0  1990  Phil Collins  Serious Hits... Live!        8                 99565.2
#
#    AxY
# 0    1

# %%
# Busqueda del album de mayor duracion.
# Album Length research.

# Consultamos al dataset para saber cual es el autor del album de mayor duracion y cual fue su año de lanzamiento.
# We consult the dataset to find out who is the author of the album with the longest duration and what was its release year.

Lenght_music = data[['Year', 'Artist', 'Album', 'Album Length']]

# Filtramos albums de una duracion mayor a '1:20:46'
# Filtering albums what have lenght more than '1:20:46'

Lenght_music_cont = Lenght_music[Lenght_music['Album Length'] > '1:20:46']['Album Length'].value_counts()

# Ordenamos en orden descendente.
# We sort in descending order.

top_15_albums = Lenght_music.sort_values(by='Album Length', ascending=False).head(15)

# Muestra final.
# Final work. 

top_15_albums[['Year', 'Artist', 'Album', 'Album Length']]
# Out:
#     Year               Artist                                   Album  \
# 0   2019               Arashi           5x20 All The Best!! 1999-2019
# 1   2017           Elton John                                Diamonds
# 2   1995      Michael Jackson  History: Past, Present & Future Book I
# 3   2015  Broadway Soundtrack                                Hamilton
# 4   2003              Outkast           Speakerboxxx / The Love Below
# ..   ...                  ...                                     ...
# 10  2021        Morgan Wallen             Dangerous: The Double Album
# 11  2007               Eagles                   Long Road Out Of Eden
# 12  2018                Drake                                Scorpion
# 13  2021                Drake                     Certified Lover Boy
# 14  2016                Drake                                   Views
#
#    Album Length
# 0       5:04:02
# 1       2:35:47
# 2       2:28:51
# 3       2:22:13
# 4       2:14:39
# ..          ...
# 10      1:30:53
# 11      1:30:46
# 12      1:29:44
# 13      1:26:02
# 14      1:21:14
#
# [15 rows x 4 columns]

# %%
# Ordenar los datos por duración de manera descendente
top_15_albums = top_15_albums.sort_values('Album Length', ascending=True)

# Obtener los datos de duración y artistas
duracion = top_15_albums['Album Length']
artistas = top_15_albums.apply(lambda row: f"{row['Artist']} - {row['Album']} - {row['Year']}", axis=1)



# Crear el gráfico de barras
plt.barh(artistas, duracion)
plt.xlabel('Artista - Álbum')
plt.ylabel('Duración del disco')
plt.title('Top 15 álbumes por duración')

# Rotar las etiquetas del eje x para una mejor legibilidad
plt.xticks(rotation=90)

# Mostrar el gráfico
plt.show()

# %%
# Busqueda de los años de mayor recaudacion
# Research the years with the highest collection

# Consultamos al dataset para saber cual es el autor del album de mayor duracion y cual fue su año de lanzamiento.
# We consult the dataset to find out who is the author of the album with the longest duration and what was its release year.

Sales_year = data[['Year', 'Artist', 'Album', 'Worldwide Sales (Est.)','Genre']]

# Filtramos albums de una duracion mayor a '260000.0'
# Filtering albums what have lenght more than '260000.0'

Sales_yearf = Sales_year[Sales_year['Worldwide Sales (Est.)'] > 260000.0]

# Ordenamos en orden descendente.
# We sort in descending order.

Big_sales_year = Sales_yearf.sort_values(by='Worldwide Sales (Est.)', ascending=False).head(15)

# Muestra final.
# Final work.

# Obtener los datos completos (Year, Artist, Album, Worldwide Sales, Genre) para los álbumes con mayores ventas
final_bigsales = Sales_year.loc[Sales_year['Worldwide Sales (Est.)'].isin(Big_sales_year['Worldwide Sales (Est.)'])]

final_bigsales[['Year', 'Artist', 'Album', 'Worldwide Sales (Est.)', 'Genre']]
# Out:
#      Year             Artist                      Album  \
# 22   2000        The Beatles                white Album
# 29   1992               ABBA       Gold - Greatest Hits
# 43   1997        Celine Dion      Let's Talk About Love
# 44   1990            Madonna  The Immaculate Collection
# 49   1997   Movie Soundtrack                    Titanic
# ..    ...                ...                        ...
# 120  1995  Alanis Morissette         Jagged Little Pill
# 194  1999    Backstreet Boys                  Milennium
# 198  2011              Adele                         21
# 256  1991            Nirvana                  Nevermind
# 259  1993       Mariah Carey                  Music Box
#
#      Worldwide Sales (Est.)      Genre
# 22                 320000.0       Rock
# 29                 320000.0        Pop
# 43                 300000.0        Pop
# 44                 300000.0        Pop
# 49                 300000.0  Classical
# ..                      ...        ...
# 120                330000.0       Rock
# 194                400000.0        Pop
# 198                300000.0        Pop
# 256                300000.0       Rock
# 259                300000.0        Pop
#
# [15 rows x 5 columns]

# %%
# Grafico de los años de mayor recaudacion
# Graph of the years with the highest collection

# Ordenar los datos por duración de manera descendente
final_bigsales = final_bigsales.sort_values('Worldwide Sales (Est.)', ascending=True)

# Obtener los datos de duración y artistas
duracion = final_bigsales['Worldwide Sales (Est.)']
artistas = final_bigsales.apply(lambda row: f"{row['Artist']} - {row['Album']} - {row['Year']}", axis=1)



# Crear el gráfico de barras
plt.barh(artistas, duracion)
plt.xlabel('Artista - Álbum')
plt.ylabel('Recaudacion')
plt.title('Top años de mayor recaudacion')

# Rotar las etiquetas del eje x para una mejor legibilidad
plt.xticks(rotation=90)

# Mostrar el gráfico
plt.show()

# %% [markdown]
# # 2° Dataset
# # 5000 ALL TIMES ALBUMS

# %%
data2.keys()
# Out:
# Index(['Ranking', 'Album', 'Artist Name', 'Release Date', 'Genres',
#        'Descriptors', 'Average Rating', 'Number of Ratings',
#        'Number of Reviews', 'Decade'],
#       dtype='object')

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Ranking            5000 non-null   float64
#  1   Album              5000 non-null   object
#  2   Artist Name        5000 non-null   object
#  3   Release Date       3068 non-null   datetime64[ns]
#  4   Genres             5000 non-null   object
#  5   Descriptors        4886 non-null   object
#  6   Average Rating     5000 non-null   float64
#  7   Number of Ratings  5000 non-null   object
#  8   Number of Reviews  5000 non-null   int64
#  9   Decade             2946 non-null   category
# dtypes: category(1), datetime64[ns](1), float64(2), int64(1), object(5)
# memory usage: 356.8+ KB

# %%
#### Podemos observar que es un dataset con mas datos. 
### Biggest dataset than before.

# Esta recopilacion desde que año cubre? 
# What year cover this dataset? 

rd = data2['Release Date'].sort_values(ascending=True)
rd.tail(2000)
# Out:
# 1547    28 October 1989
# 1546    28 October 1997
# 3304    28 October 2002
# 961     28 October 2002
# 2023    28 October 2002
#              ...
# 967      September 2002
# 1975     September 2009
# 2100     September 2009
# 4031     September 2012
# 2578     September 2017
# Name: Release Date, Length: 2000, dtype: object

# %%
#Al parecer tenemos registros desde 1966 y por ultimo 2017, veamos que artistas se encuenrtan en este ATH5000
# This dataset cover since 1966 to 2017, let's look who artist are in this ATH5000


#Top 10

DS_top_albums = data2.sort_values(by='Ranking', ascending=True)
DS_top_albums.head(10)
# Out:
#    Ranking                                              Album  \
# 0      1.0                                        OK Computer
# 1      2.0                                 Wish You Were Here
# 2      3.0                   In the Court of the Crimson King
# 3      4.0                                              Kid A
# 4      5.0                                To Pimp a Butterfly
# 5      6.0                                           Loveless
# 6      7.0                          The Dark Side of the Moon
# 7      8.0                                         Abbey Road
# 8      9.0                      The Velvet Underground & Nico
# 9     10.0  The Rise and Fall of Ziggy Stardust and the Sp...
#
#                      Artist Name       Release Date  \
# 0                      Radiohead       16 June 1997
# 1                     Pink Floyd  12 September 1975
# 2                   King Crimson    10 October 1969
# 3                      Radiohead     3 October 2000
# 4                 Kendrick Lamar      15 March 2015
# 5            My Bloody Valentine    4 November 1991
# 6                     Pink Floyd      23 March 1973
# 7                    The Beatles  26 September 1969
# 8  The Velvet Underground & Nico      12 March 1967
# 9                    David Bowie       16 June 1972
#
#                                             Genres  \
# 0                       Alternative Rock, Art Rock
# 1                       Progressive Rock, Art Rock
# 2                       Progressive Rock, Art Rock
# 3          Art Rock, Experimental Rock, Electronic
# 4  Conscious Hip Hop, West Coast Hip Hop, Jazz Rap
# 5                              Shoegaze, Noise Pop
# 6                       Art Rock, Progressive Rock
# 7                                         Pop Rock
# 8                      Art Rock, Experimental Rock
# 9                              Glam Rock, Pop Rock
#
#                                          Descriptors  Average Rating  \
# 0  melancholic, anxious, futuristic, alienation, ...            4.23
# 1  melancholic, atmospheric, progressive, male vo...            4.29
# 2  fantasy, epic, progressive, philosophical, com...            4.30
# 3  cold, melancholic, futuristic, atmospheric, an...            4.21
# 4  political, conscious, poetic, protest, concept...            4.27
# 5  noisy, ethereal, atmospheric, romantic, dense,...            4.24
# 6  philosophical, atmospheric, introspective, exi...            4.20
# 7  melodic, warm, male vocals, bittersweet, summe...            4.25
# 8  drugs, sexual, raw, urban, noisy, nihilistic, ...            4.23
# 9  science fiction, melodic, anthemic, concept al...            4.26
#
#   Number of Ratings  Number of Reviews
# 0            70,382               1531
# 1            48,662                983
# 2            44,943                870
# 3            58,590                734
# 4            44,206                379
# 5            49,887               1223
# 6            57,622               1549
# 7            44,544                961
# 8            45,570                929
# 9            39,501                721

# %%
# Final de la lista
# Tail of list

DS_top_albums.tail(10)
# Out:
#       Ranking                                         Album  \
# 4990   4991.0                          The Time of the Oath
# 4991   4992.0                                          I Am
# 4992   4993.0                     現実を超えて (Genjitsu o koete)
# 4993   4994.0                              Bring the Family
# 4994   4995.0                                       Passion
# 4995   4996.0                                     Gracious!
# 4996   4997.0                          Knights of the Cross
# 4997   4998.0             (Listen For) The Rag and Bone Man
# 4998   4999.0  Hymnen für elektronische und konkrete Klänge
# 4999   5000.0                        Adventures in Paradise
#
#                                             Artist Name      Release Date  \
# 4990                                          Helloween      5 March 1996
# 4991                                 Earth, Wind & Fire       9 June 1979
# 4992                           t e l e p a t h テレパシー能力者      26 June 2014
# 4993                                         John Hiatt          May 1987
# 4994                                          Catharsis              1999
# 4995                                           Gracious      17 July 1970
# 4996                                       Grave Digger       18 May 1998
# 4997                                 And Also the Trees  12 November 2007
# 4998  Studio für elektronische Musik des Westdeutsch...              1969
# 4999                                    Minnie Riperton       22 May 1975
#
#                                               Genres  \
# 4990                                     Power Metal
# 4991                                     Disco, Funk
# 4992                                       Vaporwave
# 4993        Singer/Songwriter, Roots Rock, Americana
# 4994                           Crust Punk, Metalcore
# 4995                Progressive Rock, Symphonic Prog
# 4996                        Power Metal, Heavy Metal
# 4997                                        Art Rock
# 4998  Musique concrète, Modern Classical, Electronic
# 4999                           Smooth Soul, Pop Soul
#
#                                             Descriptors  Average Rating  \
# 4990        energetic, melodic, male vocals, ..., heavy            3.65
# 4991  happy, summer, party, energetic, uplifting, lu...            3.68
# 4992  meditative, nocturnal, sampling, atmospheric, ...            3.67
# 4993  love, lethargic, lonely, existential, melodic,...            3.68
# 4994  male vocals, anarchism, aggressive, angry, hea...            3.65
# 4995                                                NaN            3.69
# 4996  history, male vocals, heavy, concept album, an...            3.67
# 4997  atmospheric, poetic, dark, male vocals, ominou...            3.68
# 4998  avant-garde, sampling, dense, complex, scary, ...            3.65
# 4999  lush, female vocals, romantic, uplifting, summ...            3.69
#
#      Number of Ratings  Number of Reviews
# 4990             1,542                 43
# 4991             1,108                 22
# 4992               814                 13
# 4993               727                 37
# 4994               616                  6
# 4995               565                 32
# 4996               562                 11
# 4997               524                 15
# 4998               536                 11
# 4999               490                 14

# %%
# Cuales son los 5 albums con mas reseñas?
# Who are 5 albums with most reviews?

Review = data2.sort_values(by='Number of Reviews', ascending=False)
Review.head(5)
# Out:
#     Ranking                      Album          Artist Name      Release Date  \
# 6       7.0  The Dark Side of the Moon           Pink Floyd     23 March 1973
# 0       1.0                OK Computer            Radiohead      16 June 1997
# 5       6.0                   Loveless  My Bloody Valentine   4 November 1991
# 10     11.0                   Revolver          The Beatles     5 August 1966
# 30     31.0  The Beatles [White Album]          The Beatles  22 November 1968
#
#                         Genres  \
# 6   Art Rock, Progressive Rock
# 0   Alternative Rock, Art Rock
# 5          Shoegaze, Noise Pop
# 10   Pop Rock, Psychedelic Pop
# 30              Pop Rock, Rock
#
#                                           Descriptors  Average Rating  \
# 6   philosophical, atmospheric, introspective, exi...            4.20
# 0   melancholic, anxious, futuristic, alienation, ...            4.23
# 5   noisy, ethereal, atmospheric, romantic, dense,...            4.24
# 10  psychedelic, melodic, male vocals, drugs, ecle...            4.23
# 30  eclectic, melodic, playful, male vocals, quirk...            4.14
#
#    Number of Ratings  Number of Reviews
# 6             57,622               1549
# 0             70,382               1531
# 5             49,887               1223
# 10            43,178               1160
# 30            35,545               1085

# %%
# Cuantos discos de 'The Beatles' aparecen en esta seleccion? 
# How many albums of 'The Beatles' are in this dataset?

SA = data2[data2['Artist Name'] == 'The Beatles']
SA
# Out:
#       Ranking                                  Album  Artist Name  \
# 7         8.0                             Abbey Road  The Beatles
# 10       11.0                               Revolver  The Beatles
# 23       24.0  Sgt. Pepper's Lonely Hearts Club Band  The Beatles
# 30       31.0              The Beatles [White Album]  The Beatles
# 72       73.0                            Rubber Soul  The Beatles
# 78       79.0                   Magical Mystery Tour  The Beatles
# 1894   1895.0                                  Help!  The Beatles
# 1957   1958.0                                   Love  The Beatles
# 2155   2156.0                     A Hard Day's Night  The Beatles
# 4818   4819.0                              Let It Be  The Beatles
#
#            Release Date                              Genres  \
# 7     26 September 1969                            Pop Rock
# 10        5 August 1966           Pop Rock, Psychedelic Pop
# 23          1 June 1967           Psychedelic Pop, Pop Rock
# 30     22 November 1968                      Pop Rock, Rock
# 72      3 December 1965                            Pop Rock
# 78     27 November 1967           Psychedelic Pop, Pop Rock
# 1894      6 August 1965                            Pop Rock
# 1957   26 November 2006  Pop Rock, Mashup, Psychedelic Rock
# 2155       10 July 1964                Merseybeat, Pop Rock
# 4818        18 May 1970                            Pop Rock
#
#                                             Descriptors  Average Rating  \
# 7     melodic, warm, male vocals, bittersweet, summe...            4.25
# 10    psychedelic, melodic, male vocals, drugs, ecle...            4.23
# 23    psychedelic, playful, melodic, male vocals, wa...            4.13
# 30    eclectic, melodic, playful, male vocals, quirk...            4.14
# 72    melodic, love, male vocals, bittersweet, roman...            4.03
# 78    psychedelic, melodic, playful, surreal, male v...            4.06
# 1894  bittersweet, melodic, love, male vocals, roman...            3.67
# 1957  melodic, male vocals, mashup, psychedelic, hyp...            3.75
# 2155  love, romantic, melodic, male vocals, energeti...            3.65
# 4818  male vocals, melodic, warm, bittersweet, energ...            3.55
#
#      Number of Ratings  Number of Reviews
# 7               44,544                961
# 10              43,178               1160
# 23              43,576                863
# 30              35,545               1085
# 72              33,508                721
# 78              27,318                560
# 1894            20,697                380
# 1957             2,309                142
# 2155            20,388                462
# 4818            21,363                414

# %%
# Cuantos discos de 'Pink Floyd' aparecen en esta seleccion? 
# How many albums of 'Pink Floyd' are in this dataset?

SA2 = data2[data2['Artist Name'] == 'Pink Floyd']
SA2
# Out:
#       Ranking                           Album Artist Name       Release Date  \
# 1         2.0              Wish You Were Here  Pink Floyd  12 September 1975
# 6         7.0       The Dark Side of the Moon  Pink Floyd      23 March 1973
# 32       33.0                         Animals  Pink Floyd    21 January 1977
# 138     139.0                          Meddle  Pink Floyd    5 November 1971
# 270     271.0  The Piper at the Gates of Dawn  Pink Floyd      4 August 1967
# 288     289.0                        The Wall  Pink Floyd   30 November 1979
# 3004   3005.0          A Saucerful of Secrets  Pink Floyd       29 June 1968
# 3656   3657.0               Atom Heart Mother  Pink Floyd     2 October 1970
#
#                                   Genres  \
# 1             Progressive Rock, Art Rock
# 6             Art Rock, Progressive Rock
# 32            Progressive Rock, Art Rock
# 138                     Progressive Rock
# 270    Psychedelic Rock, Psychedelic Pop
# 288                 Rock Opera, Art Rock
# 3004                    Psychedelic Rock
# 3656  Progressive Rock, Psychedelic Rock
#
#                                             Descriptors  Average Rating  \
# 1     melancholic, atmospheric, progressive, male vo...            4.29
# 6     philosophical, atmospheric, introspective, exi...            4.20
# 32    political, pessimistic, philosophical, sarcast...            4.13
# 138   mellow, psychedelic, atmospheric, mysterious, ...            3.96
# 270   psychedelic, drugs, fantasy, surreal, playful,...            3.86
# 288   misanthropic, rock opera, lonely, concept albu...            3.80
# 3004  psychedelic, surreal, mysterious, space, atmos...            3.64
# 3656  psychedelic, peaceful, progressive, suite, mal...            3.60
#
#      Number of Ratings  Number of Reviews
# 1               48,662                983
# 6               57,622               1549
# 32              36,462                695
# 138             27,730                531
# 270             28,446                691
# 288             36,827                747
# 3004            17,144                316
# 3656            18,989                364

# %%
# tops albums 1992

R1992D = data2['Release Date'].str.contains('1992')
selected_1992 = data2[R1992D]
selected_1992
# Out:
#       Ranking                             Album               Artist Name  \
# 90       91.0      Selected Ambient Works 85-92                Aphex Twin
# 164     165.0          Rage Against the Machine  Rage Against the Machine
# 213     214.0                              Dirt           Alice in Chains
# 242     243.0                      Bone Machine                 Tom Waits
# 283     284.0     Twin Peaks: Fire Walk With Me        Angelo Badalamenti
# ...       ...                               ...                       ...
# 4423   4424.0                         Propeller          Guided by Voices
# 4641   4642.0                      The Predator                  Ice Cube
# 4665   4666.0  Megalázottak és megszomorítottak              After Crying
# 4835   4836.0                  Music to Driveby      Comptons Most Wanted
# 4966   4967.0                              Pure                  Godflesh
#
#            Release Date                                             Genres  \
# 90      9 November 1992                                Ambient Techno, IDM
# 164    10 November 1992                       Rap Metal, Alternative Metal
# 213   29 September 1992                          Grunge, Alternative Metal
# 242    8 September 1992               Singer/Songwriter, Experimental Rock
# 283      11 August 1992                              Film Score, Dark Jazz
# ...                 ...                                                ...
# 4423               1992                   Lo-Fi / Slacker Rock, Indie Rock
# 4641   17 November 1992  West Coast Hip Hop, Gangsta Rap, Political Hip...
# 4665               1992                   Progressive Rock, Symphonic Prog
# 4835  29 September 1992                    Gangsta Rap, West Coast Hip Hop
# 4966         April 1992                                   Industrial Metal
#
#                                             Descriptors  Average Rating  \
# 90    atmospheric, ethereal, futuristic, instrumenta...            4.03
# 164   political, protest, aggressive, angry, rebelli...            3.94
# 213   drugs, heavy, depressive, pessimistic, angry, ...            3.93
# 242   dark, raw, nocturnal, death, manic, ominous, e...            3.98
# 283   nocturnal, dark, atmospheric, surreal, mysteri...            4.01
# ...                                                 ...             ...
# 4423  lo-fi, melodic, noisy, raw, bittersweet, male ...            3.68
# 4641  crime, political, violence, urban, angry, male...            3.66
# 4665  nocturnal, poetic, progressive, dark, mellow, ...            3.69
# 4835  urban, sampling, male vocals, crime, lethargic...            3.68
# 4966  mechanical, heavy, misanthropic, noisy, dark, ...            3.66
#
#      Number of Ratings  Number of Reviews
# 90              27,921                300
# 164             22,122                439
# 213             18,181                452
# 242              9,452                171
# 283              2,939                 16
# ...                ...                ...
# 4423             2,008                 48
# 4641             2,711                 56
# 4665               496                 16
# 4835               753                 20
# 4966             1,836                 24
#
# [97 rows x 9 columns]

# %%
# Top albums 2002 

R2002D = data2['Release Date'].str.contains('2002')
selected_2002 = data2[R2002D]
selected_2002
# Out:
#       Ranking                      Album              Artist Name  \
# 149     150.0  Turn On the Bright Lights                 Interpol
# 187     188.0         Songs for the Deaf  Queens of the Stone Age
# 204     205.0                   Geogaddi         Boards of Canada
# 220     221.0       Yankee Hotel Foxtrot                    Wilco
# 244     245.0        Cowboy Bebop CD-Box   Yoko Kanno / Seatbelts
# ...       ...                        ...                      ...
# 4888   4889.0          The Remote Viewer                     Coil
# 4895   4896.0          The Sullen Sulcus        Mourning Beloveth
# 4908   4909.0                      Trust                      Low
# 4982   4983.0         Demons Dance Alone            The Residents
# 4984   4985.0           The True Meaning                  Cormega
#
#           Release Date                                    Genres  \
# 149     20 August 2002                         Post-Punk Revival
# 187     27 August 2002             Stoner Rock, Alternative Rock
# 204   18 February 2002                                       IDM
# 220      23 April 2002                                Indie Rock
# 244       21 June 2002               Television Music, Jazz, Pop
# ...                ...                                       ...
# 4888          May 2002  Tribal Ambient, Experimental, Electronic
# 4895  15 December 2002                          Death Doom Metal
# 4908   21 October 2002                                  Slowcore
# 4982          May 2002                Art Pop, Experimental Rock
# 4984      25 June 2002      East Coast Hip Hop, Hardcore Hip Hop
#
#                                             Descriptors  Average Rating  \
# 149   urban, melancholic, atmospheric, anxious, noct...            3.95
# 187   desert, energetic, concept album, male vocals,...            3.94
# 204   mysterious, psychedelic, atmospheric, ominous,...            3.96
# 220   melancholic, bittersweet, male vocals, poetic,...            3.92
# 244   eclectic, male vocals, melodic, female vocals,...            4.03
# ...                                                 ...             ...
# 4888  atmospheric, instrumental, mysterious, hypnoti...            3.66
# 4895  male vocals, melancholic, melodic, depressive,...            3.68
# 4908  sad, lethargic, sombre, melancholic, atmospher...            3.67
# 4982  male vocals, female vocals, introspective, mel...            3.67
# 4984  introspective, rhythmic, sampling, urban, boas...            3.70
#
#      Number of Ratings  Number of Reviews
# 149             26,724                490
# 187             22,755                346
# 204             16,637                191
# 220             21,466                371
# 244                594                  6
# ...                ...                ...
# 4888             1,142                 13
# 4895               490                  5
# 4908             2,255                 37
# 4982               651                 15
# 4984               388                  9
#
# [105 rows x 9 columns]

# %%
# Tops albums 2012 

R2012D = data2['Release Date'].str.contains('2012')
selected_2012 = data2[R2012D]
selected_2012
# Out:
#       Ranking                   Album        Artist Name       Release Date  \
# 16       17.0  good kid, m.A.A.d city     Kendrick Lamar    22 October 2012
# 61       62.0         The Money Store        Death Grips      24 April 2012
# 234     235.0                The Seer              Swans     28 August 2012
# 470     471.0          channel ORANGE        Frank Ocean       10 July 2012
# 471     472.0    Mista Thug Isolation      Lil Ugly Mane   11 February 2012
# ...       ...                     ...                ...                ...
# 4289   4290.0              The Master    Jonny Greenwood  11 September 2012
# 4293   4294.0                 Journey     Austin Wintory      10 April 2012
# 4338   4339.0                   Trick             Alex G    6 November 2012
# 4462   4463.0               Monomania  Car Seat Headrest      1 August 2012
# 4821   4822.0         Weather Systems           Anathema      16 April 2012
#
#                                                  Genres  \
# 16                West Coast Hip Hop, Conscious Hip Hop
# 61    Industrial Hip Hop, Hardcore Hip Hop, Experime...
# 234                        Experimental Rock, Post-Rock
# 470                   Alternative R&B, Contemporary R&B
# 471                       Memphis Rap, Southern Hip Hop
# ...                                                 ...
# 4289           Film Score, Modern Classical, Orchestral
# 4293     Video Game Music, Ambient, Cinematic Classical
# 4338  Lo-Fi / Slacker Rock, Singer/Songwriter, Bedro...
# 4462            Lo-Fi / Slacker Rock, Singer/Songwriter
# 4821                                   Progressive Rock
#
#                                             Descriptors  Average Rating  \
# 16    urban, crime, concept album, conscious, intros...            4.20
# 61    aggressive, manic, energetic, angry, noisy, ni...            4.02
# 234   apocalyptic, repetitive, ominous, epic, dark, ...            3.93
# 470   romantic, sexual, lonely, warm, summer, LGBT, ...            3.79
# 471   drugs, misanthropic, vulgar, dark, crime, humo...            3.87
# ...                                                 ...             ...
# 4289  mysterious, anxious, atmospheric, orchestral, ...            3.71
# 4293  desert, peaceful, meditative, ethereal, atmosp...            3.70
# 4338  melodic, lo-fi, lonely, calm, bittersweet, mal...            3.67
# 4462  breakup, lo-fi, LGBT, angry, bittersweet, lone...            3.67
# 4821  passionate, spiritual, love, melancholic, upli...            3.63
#
#      Number of Ratings  Number of Reviews
# 16              38,939                315
# 61              36,403                311
# 234             16,591                253
# 470             24,446                182
# 471             10,944                 62
# ...                ...                ...
# 4289               824                  9
# 4293               601                  7
# 4338             3,311                 13
# 4462             2,409                 17
# 4821             3,159                101
#
# [30 rows x 9 columns]

# %%
# Vemos menor cantidad de seleccion de albums post 2000.
# We can see less selection of album after year 2000

# %%
# Creamos una variable en donde se convierta nuestra columna 'Release Date' en una fecha 

data2['Release Date'] = pd.to_datetime(data2['Release Date'], format='%d %B %Y', errors='coerce')

data2['Release Date']
# Out:
# 0      1997-06-16
# 1      1975-09-12
# 2      1969-10-10
# 3      2000-10-03
# 4      2015-03-15
#           ...
# 4995   1970-07-17
# 4996   1998-05-18
# 4997   2007-11-12
# 4998          NaT
# 4999   1975-05-22
# Name: Release Date, Length: 5000, dtype: datetime64[ns]

# %%
# Creamos una variable en donde se convierta nuestra columna 'Release Date' por decadas. 

bin_edges = [i for i in range(1957, 2019, 10)]
bin_labels = [f"{i}-{i+9}" for i in range(1957, 2017, 10)]
data2['Decade'] = pd.cut(data2['Release Date'].dt.year, bins=bin_edges, labels=bin_labels)

# %%
#Grafico x cantidad de albums por decada : 
sns.histplot(data=data2, x='Decade', hue='Decade', multiple='stack')
plt.show()

# %% [markdown]
# # Géneros

# %%
data2['Genres'].value_counts()
# Out:
# Progressive Rock                                          108
# Hard Bop                                                   97
# Death Metal                                                62
# Hard Rock                                                  55
# Thrash Metal                                               53
#                                                          ...
# Nueva canción española, Singer/Songwriter, Baroque Pop      1
# Pop Rock, Mashup, Psychedelic Rock                          1
# Noise Pop, J-Rock                                           1
# Ambient, Ambient Techno                                     1
# Musique concrète, Modern Classical, Electronic              1
# Name: Genres, Length: 2168, dtype: int64

# %%
#ETL and group ;

generos_grandes = data2['Genres'].value_counts()

# Filtrar los valores que tienen al menos 10 o más repeticiones
generos_abarcativo = generos_grandes[generos_grandes >= 10]

# Obtener los géneros correspondientes a los valores filtrados
generos_abarcativo = generos_abarcativo.index

# Filtrar el DataFrame original por los géneros seleccionados
df_filtrado = data2[data2['Genres'].isin(generos_abarcativo)]

# Obtener los conteos de cada género en el DataFrame filtrado
conteo_generos = df_filtrado['Genres'].value_counts()

# Calcular los porcentajes de cada género
porcentajes_generos = conteo_generos / conteo_generos.sum() * 100

porcentajes_generos
# Out:
# Progressive Rock                      6.945338
# Hard Bop                              6.237942
# Death Metal                           3.987138
# Hard Rock                             3.536977
# Thrash Metal                          3.408360
#                                         ...
# Grindcore                             0.643087
# Slowcore                              0.643087
# Singer/Songwriter, Indie Folk         0.643087
# Jangle Pop, Indie Pop                 0.643087
# Progressive Rock, Psychedelic Rock    0.643087
# Name: Genres, Length: 67, dtype: float64

# %%
# Filtrar los porcentajes de géneros mayores a un valor específico (por ejemplo, 3%)
# Filter gender percentages greater than a specific value (for example, 3%)
porcentajes_filtrados = porcentajes_generos[porcentajes_generos > 3]

# Crear el gráfico de barras
# Create bars graphic

plt.figure(figsize=(11, 5))
plt.bar(porcentajes_filtrados.index, porcentajes_filtrados)

# Personalizar el gráfico
# Personalize graph

plt.xlabel('Géneros')
plt.ylabel('Porcentaje')
plt.title('Porcentaje de Géneros Musicales')
plt.xticks(rotation=90)

# Mostrar el gráfico
# Show graph

plt.show()
